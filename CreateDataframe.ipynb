# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .master("local[*]") \
        .appName("SparkTest") \
        .getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[60], line 6
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4         .master("local[*]") \
#       5         .appName("SparkTest") \
# ----> 6         .getOrCreate()
#       8 spark
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\session.py:552, in SparkSession.Builder.getOrCreate(self)
#     550 session = SparkSession._instantiatedSession
#     551 if session is None or session._sc._jsc is None:
# --> 552     sparkConf = SparkConf()
#     553     for key, value in self._options.items():
#     554         sparkConf.set(key, value)
#
# File D:\spark_setup_folder\spark\python\pyspark\conf.py:136, in SparkConf.__init__(self, loadDefaults, _jvm, _jconf)
#     132     jvm = _jvm or SparkContext._jvm
#     134 if jvm is not None:
# ...

# %%
df = spark.read.format('csv'). \
     option('Header',True). \
     option('InferSchema',True). \
     load("D:\Datasets\students_sample.csv")

# %%
df.show(10)
# Out:
# +---+------+---+---+---+---+---------+
# |_c0|   _c1|_c2|_c3|_c4|_c5|      _c6|
# +---+------+---+---+---+---+---------+
# |  1| Aarav|  M| 15|10A| 85|    Delhi|
# |  2|Ananya|  F| 14| 9B| 78|   Mumbai|
# |  3| Rohan|  M| 16|10B| 92|     Pune|
# |  4| Priya|  F| 15|10A| 88|Bangalore|
# |  5| Karan|  M| 14| 9A| 67|  Chennai|
# |  6|  Neha|  F| 15|10C| 90|Hyderabad|
# |  7| Arjun|  M| 16|11A| 73|    Delhi|
# |  8|  Isha|  F| 14| 9C| 81|   Jaipur|
# |  9|Vikram|  M| 15|10B| 59|   Indore|
# | 10| Sneha|  F| 16|11B| 95|     Pune|
# +---+------+---+---+---+---+---------+
# only showing top 10 rows

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: integer (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: integer (nullable = true)
#  |-- _c6: string (nullable = true)

# %%
df = df.toDF('Id','name','gender','age','section','marks','city')

# %%
df.show(10)
# Out:
# +---+------+------+---+-------+-----+---------+
# | Id|  name|gender|age|section|marks|     city|
# +---+------+------+---+-------+-----+---------+
# |  1| Aarav|     M| 15|    10A|   85|    Delhi|
# |  2|Ananya|     F| 14|     9B|   78|   Mumbai|
# |  3| Rohan|     M| 16|    10B|   92|     Pune|
# |  4| Priya|     F| 15|    10A|   88|Bangalore|
# |  5| Karan|     M| 14|     9A|   67|  Chennai|
# |  6|  Neha|     F| 15|    10C|   90|Hyderabad|
# |  7| Arjun|     M| 16|    11A|   73|    Delhi|
# |  8|  Isha|     F| 14|     9C|   81|   Jaipur|
# |  9|Vikram|     M| 15|    10B|   59|   Indore|
# | 10| Sneha|     F| 16|    11B|   95|     Pune|
# +---+------+------+---+-------+-----+---------+
# only showing top 10 rows

# %% [markdown]
# # AGENDA

# %% [markdown]
# SCHEMA ENFORCEMENT
# How to check Data Type    printSchema
# HOW to define Schema      using .schema
# How to change a data_type  withColumn transformation
# how to inferSchema in 2 way  structType + string

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-8EMB90P9.lan:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkTest</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
#      "order_id": 1001,
#     "order_date": "2024-01-15",
#     "ship_date": "2024-01-18",
#     "customer_id": "C101",
#     "customer_name": "Aarav Sharma",
#     "product": "Laptop",
#     "category": "Electronics",
#     "quantity": 1,
#     "price": 65000,
#     "payment_mode": "Credit Card",
#     "city": "Delhi",
#     "order_status": "Delivered"

# %% [markdown]
# # First Method to define Schema

# %%
schema = 'order_id Integer, order_date String, ship_date String, customer_id String, customer_name String, product String, category String, quatity Integer, price Long, payment_mode String, city String, order_staus String'

# %% [markdown]
# # Second Method to define Schema

# %% [markdown]
#      "order_id": 1001,
#     "order_date": "2024-01-15",
#     "ship_date": "2024-01-18",
#     "customer_id": "C101",
#     "customer_name": "Aarav Sharma",
#     "product": "Laptop",
#     "category": "Electronics",
#     "quantity": 1,
#     "price": 65000,
#     "payment_mode": "Credit Card",
#     "city": "Delhi",
#     "order_status": "Delivered"

# %%
from pyspark.sql.types import *
schema_struct = StructType([
    StructField('order_date',DateType()),
    StructField('ship_date',DateType()),
    StructField('customer_id',LongType()),
    StructField('customer_name',StringType()),
    StructField('product',StringType()),
    StructField('category',StringType()),
    StructField('quantity',LongType()),
    StructField('price',LongType()),
    StructField('payment_mode',StringType()),
    StructField('city',StringType()),
    StructField('order_status',StringType())
])

# %%
orders = spark.read.format('json'). \
     option('Multiline',True). \
      schema(schema_struct). \
     load("D:\Datasets\orders_sample.json")

# %%
orders.printSchema()
# Out:
# root
#  |-- order_date: date (nullable = true)
#  |-- ship_date: date (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- price: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %% [markdown]
# # Nested Schema

# %% [markdown]
# ### 2 Ways to tackle the nested schema
# #### String Method
# #### StructType()

# %% [markdown]
#   {
#     "patient_id": 101,
#     "name": {
#       "first_name": "Amit",
#       "last_name": "Sharma"
#     },
#     "gender": "Male",
#     "age": 45,
#     "diagnosis": "Diabetes",
#     "admission_date": "2024-01-15",
#     "city": "Delhi"
#   },

# %%
patient = spark.read.format('json'). \
     option('Multiline',True). \
     option('InferSchema',True). \
     load("D:\Datasets\patient_data_nested.json")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 patient = spark.read.format('json'). \
#       2      option('Multiline',True). \
#       3      option('InferSchema',True). \
#       4      load("D:\Datasets\patient_data_nested.json")
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\session.py:1898, in SparkSession.read(self)
#    1861 @property
#    1862 def read(self) -> DataFrameReader:
#    1863     """
#    1864     Returns a :class:`DataFrameReader` that can be used to read data
#    1865     in as a :class:`DataFrame`.
#    (...)
#    1896     +---+------------+
#    1897     """
# -> 1898     return DataFrameReader(self)
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\readwriter.py:69, in DataFrameReader.__init__(self, spark)
#      68 def __init__(self, spark: "SparkSession"):
# ...

# %%
patient.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 patient.show()
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\classic\dataframe.py:285, in DataFrame.show(self, n, truncate, vertical)
#     284 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# --> 285     print(self._show_string(n, truncate, vertical))
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\classic\dataframe.py:303, in DataFrame._show_string(self, n, truncate, vertical)
#     297     raise PySparkTypeError(
#     298         errorClass="NOT_BOOL",
#     299         messageParameters={"arg_name": "vertical", "arg_type": type(vertical).__name__},
#     300     )
#     302 if isinstance(truncate, bool) and truncate:
# --> 303     return self._jdf.showString(n, 20, vertical)
#     304 else:
#     305     try:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\session.py:681, in SparkSession._repr_html_(self)
#     674 def _repr_html_(self) -> str:
#     675     return """
#     676         <div>
#     677             <p><b>SparkSession - {catalogImplementation}</b></p>
#     678             {sc_HTML}
#     679         </div>
#     680     """.format(
# --> 681         catalogImplementation=self.conf.get("spark.sql.catalogImplementation"),
#     682         sc_HTML=self.sparkContext._repr_html_(),
#     683     )
#
# ...

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 spark.stop()
#
# File D:\spark_setup_folder\spark\python\pyspark\sql\session.py:2023, in SparkSession.stop(self)
#    2009 """
#    2010 Stop the underlying :class:`SparkContext`.
#    2011
#    (...)
#    2019 >>> spark.stop()  # doctest: +SKIP
#    2020 """
#    2021 from pyspark.sql.context import SQLContext
# -> 2023 self._sc.stop()
#    2024 # We should clean the default session up. See SPARK-23228.
#    2025 assert self._jvm is not None
#
# File D:\spark_setup_folder\spark\python\pyspark\core\context.py:684, in SparkContext.stop(self)
#     682 if getattr(self, "_jsc", None):
#     683     try:
# --> 684         self._jsc.stop()
#     685     except Py4JError:
#     686         # Case: SPARK-18523
#     687         warnings.warn(
# ...
